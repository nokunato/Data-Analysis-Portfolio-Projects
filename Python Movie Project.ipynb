# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize']=(12,8)

# Read in the data

df = pd.read_csv(r'C:\Users\Oluwanifemi\Documents\Data Projects\movie industry data\movies.csv')

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# 0             Stephen King  Jack Nicholson  United Kingdom  19000000.0
# 1  Henry De Vere Stacpoole  Brooke Shields   United States   4500000.0
# 2           Leigh Brackett     Mark Hamill   United States  18000000.0
# 3             Jim Abrahams     Robert Hays   United States   3500000.0
# 4       Brian Doyle-Murray     Chevy Chase   United States   6000000.0
#
#          gross             company  runtime
# 0   46998772.0        Warner Bros.    146.0
# 1   58853106.0   Columbia Pictures    104.0
# 2  538375067.0           Lucasfilm    124.0
# 3   83453539.0  Paramount Pictures     88.0
# 4   39846344.0      Orion Pictures     98.0

# %%
# let's see if there's any missing data

for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, pct_missing))
# Out:
# name - 0.0%
# rating - 0.010041731872717789%
# genre - 0.0%
# year - 0.0%
# released - 0.0002608242044861763%
# score - 0.0003912363067292645%
# votes - 0.0003912363067292645%
# director - 0.0%
# writer - 0.0003912363067292645%
# star - 0.00013041210224308815%
# country - 0.0003912363067292645%
# budget - 0.2831246739697444%
# gross - 0.02464788732394366%
# company - 0.002217005738132499%
# runtime - 0.0005216484089723526%

# %%
# column datatypes

df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
# fill empty columns as o
df = df.fillna(0)

# change data types
df['budget'] = df['budget'].astype('int64')
df['gross'] = df['gross'].astype('int64')

# %%
df['correct_year'] = df['released'].astype(str).str[:4]

df.head()
# Out:
#    name  rating  genre  year  released  score      votes  director  writer  \
# 0  6587       7      6  1980      1706    8.4   927000.0      2589    4015
# 1  5573       7      1  1980      1493    5.8    65000.0      2269    1633
# 2  5142       5      0  1980      1772    8.7  1200000.0      1111    2568
# 3   286       5      4  1980      1493    7.7   221000.0      1301    2001
# 4  1027       7      4  1980      1544    7.3   108000.0      1054     522
#
#    star  country    budget      gross  company  runtime correct_year
# 0  1048       55  19000000   46998772     2320    146.0         1706
# 1   328       56   4500000   58853106      732    104.0         1493
# 2  1746       56  18000000  538375067     1541    124.0         1772
# 3  2247       56   3500000   83453539     1813     88.0         1493
# 4   411       56   6000000   39846344     1778     98.0         1544

# %%
df_sort = df.sort_values(by=['gross'], inplace=False, ascending=False)

df_sort.head()
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 5445   533       6      0  2009       697    7.8  1100000.0      1155    1779
# 7445   535       6      0  2019       184    8.4   903000.0       162     744
# 3045  6896       6      6  1997       705    7.8  1100000.0      1155    1779
# 6663  5144       6      0  2015       699    7.8   876000.0      1125    2551
# 7244   536       6      0  2018       193    8.4   897000.0       162     744
#
#       star  country     budget       gross  company  runtime  correct_year
# 5445  2335       56  237000000  2847246203     2254    162.0            11
# 7445  2242       56  356000000  2797501328     1607    181.0             9
# 3045  1596       56  200000000  2201647264     2254    194.0            11
# 6663   525       56  245000000  2069521700     1541    138.0            11
# 7244  2242       56  321000000  2048359754     1607    149.0             9

# %%
# to display all the rows in the database
pd.set_option('display.max_rows', None)

# %%
#Drop any duplicates
df.drop_duplicates().head()
# Out:
#    name  rating  genre  year  released  score      votes  director  writer  \
# 0  6587       7      6  1980      1706    8.4   927000.0      2589    4015
# 1  5573       7      1  1980      1493    5.8    65000.0      2269    1633
# 2  5142       5      0  1980      1772    8.7  1200000.0      1111    2568
# 3   286       5      4  1980      1493    7.7   221000.0      1301    2001
# 4  1027       7      4  1980      1544    7.3   108000.0      1054     522
#
#    star  country    budget      gross  company  runtime  correct_year
# 0  1048       55  19000000   46998772     2320    146.0            15
# 1   328       56   4500000   58853106      732    104.0            14
# 2  1746       56  18000000  538375067     1541    124.0            15
# 3  2247       56   3500000   83453539     1813     88.0            14
# 4   411       56   6000000   39846344     1778     98.0            14

# %%
df.head()
# Out:
#    name  rating  genre  year  released  score      votes  director  writer  \
# 0  6587       7      6  1980      1706    8.4   927000.0      2589    4015
# 1  5573       7      1  1980      1493    5.8    65000.0      2269    1633
# 2  5142       5      0  1980      1772    8.7  1200000.0      1111    2568
# 3   286       5      4  1980      1493    7.7   221000.0      1301    2001
# 4  1027       7      4  1980      1544    7.3   108000.0      1054     522
#
#    star  country    budget      gross  company  runtime  correct_year
# 0  1048       55  19000000   46998772     2320    146.0            15
# 1   328       56   4500000   58853106      732    104.0            14
# 2  1746       56  18000000  538375067     1541    124.0            15
# 3  2247       56   3500000   83453539     1813     88.0            14
# 4   411       56   6000000   39846344     1778     98.0            14

# %%
#budget high correlation
#company high correlation

# %%
# Scatter plot with budget vs gross

plt.scatter(x=df['budget'], y=df['gross'])

plt.title('Budget vs Gross Earnings')

plt.xlabel('Gross Earnings')

plt.ylabel('Budget for film')

plt.show()

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# 0             Stephen King  Jack Nicholson  United Kingdom  19000000
# 1  Henry De Vere Stacpoole  Brooke Shields   United States   4500000
# 2           Leigh Brackett     Mark Hamill   United States  18000000
# 3             Jim Abrahams     Robert Hays   United States   3500000
# 4       Brian Doyle-Murray     Chevy Chase   United States   6000000
#
#        gross             company  runtime correct_year
# 0   46998772        Warner Bros.    146.0         June
# 1   58853106   Columbia Pictures    104.0         July
# 2  538375067           Lucasfilm    124.0         June
# 3   83453539  Paramount Pictures     88.0         July
# 4   39846344      Orion Pictures     98.0         July

# %%
#plt budget vs gross using seaborn

sns.regplot(x='budget', y='gross', data=df, scatter_kws={"color": "red"}, line_kws={"color":"blue"})
# Out:
# <AxesSubplot:xlabel='budget', ylabel='gross'>

# %%
#looking at correlations

df.corr(method='pearson') #pearson, kendall, spearman
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.092616  0.222427  0.309212  0.261900  0.116358
# score    0.092616  1.000000  0.407101  0.056863  0.186012  0.394564
# votes    0.222427  0.407101  1.000000  0.486931  0.632870  0.306984
# budget   0.309212  0.056863  0.486931  1.000000  0.750157  0.268372
# gross    0.261900  0.186012  0.632870  0.750157  1.000000  0.244339
# runtime  0.116358  0.394564  0.306984  0.268372  0.244339  1.000000

# %%
correlation_matrix = df.corr(method='pearson')

sns.heatmap(correlation_matrix, annot=True)

plt.title('Correlation matrix for numeric features')

plt.xlabel('Movie features')

plt.ylabel('Movie features')

plt.show()

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# 0             Stephen King  Jack Nicholson  United Kingdom  19000000
# 1  Henry De Vere Stacpoole  Brooke Shields   United States   4500000
# 2           Leigh Brackett     Mark Hamill   United States  18000000
# 3             Jim Abrahams     Robert Hays   United States   3500000
# 4       Brian Doyle-Murray     Chevy Chase   United States   6000000
#
#        gross             company  runtime correct_year
# 0   46998772        Warner Bros.    146.0         June
# 1   58853106   Columbia Pictures    104.0         July
# 2  538375067           Lucasfilm    124.0         June
# 3   83453539  Paramount Pictures     88.0         July
# 4   39846344      Orion Pictures     98.0         July

# %%
df_numerized = df

for col_name in df_numerized.columns:
    if(df_numerized[col_name].dtype == 'object'):
        df_numerized[col_name] = df_numerized[col_name].astype('category')
        df_numerized[col_name] = df_numerized[col_name].cat.codes
        
df_numerized.head()
# Out:
#    name  rating  genre  year  released  score      votes  director  writer  \
# 0  6587       7      6  1980      1706    8.4   927000.0      2589    4015
# 1  5573       7      1  1980      1493    5.8    65000.0      2269    1633
# 2  5142       5      0  1980      1772    8.7  1200000.0      1111    2568
# 3   286       5      4  1980      1493    7.7   221000.0      1301    2001
# 4  1027       7      4  1980      1544    7.3   108000.0      1054     522
#
#    star  country    budget      gross  company  runtime  correct_year
# 0  1048       55  19000000   46998772     2320    146.0            15
# 1   328       56   4500000   58853106      732    104.0            14
# 2  1746       56  18000000  538375067     1541    124.0            15
# 3  2247       56   3500000   83453539     1813     88.0            14
# 4   411       56   6000000   39846344     1778     98.0            14

# %%
correlation_matrix = df.corr(method='pearson')

sns.heatmap(correlation_matrix, annot=True)

plt.title('Correlation matrix for numeric features')

plt.xlabel('Movie features')

plt.ylabel('Movie features')

plt.show()

# %%
correlation_mat = df_numerized.corr()

corr_pairs = correlation_mat.unstack()

corr_pairs
# Out:
# name          name            1.000000
#               rating         -0.008069
#               genre           0.016355
#               year            0.011453
#               released       -0.011311
#               score           0.016377
#               votes           0.013038
#               director        0.009079
#               writer          0.009081
#               star            0.006472
#               country        -0.010737
#               budget          0.020548
#               gross           0.006989
#               company         0.009211
#               runtime         0.008483
#               correct_year   -0.013132
# rating        name           -0.008069
#               rating          1.000000
#               genre           0.072423
#               year            0.008779
#               released        0.016613
#               score           0.006192
#               votes           0.033743
#               director        0.019483
#               writer         -0.005921
#               star            0.013405
#               country         0.081244
#               budget         -0.081939
#               gross          -0.095450
#               company        -0.032943
#               runtime         0.064133
#               correct_year    0.012429
# genre         name            0.016355
#               rating          0.072423
#               genre           1.000000
#               year           -0.081261
#               released        0.029822
#               score           0.027384
#               votes          -0.145296
#               director       -0.015258
#               writer          0.006567
#               star           -0.005477
#               country        -0.037615
#               budget         -0.334021
#               gross          -0.234297
#               company        -0.071067
#               runtime        -0.052914
#               correct_year    0.027305
# year          name            0.011453
#               rating          0.008779
#               genre          -0.081261
#               year            1.000000
#               released       -0.000695
#               score           0.092616
#               votes           0.222427
#               director       -0.020795
#               writer         -0.008656
#               star           -0.027242
#               country        -0.070938
#               budget          0.309212
#               gross           0.261900
#               company        -0.010431
#               runtime         0.116358
#               correct_year   -0.002885
# released      name           -0.011311
#               rating          0.016613
#               genre           0.029822
#               year           -0.000695
#               released        1.000000
#               score           0.039814
#               votes           0.015878
#               director       -0.001478
#               writer         -0.002404
#               star            0.015777
#               country        -0.020427
#               budget          0.009145
#               gross           0.000519
#               company        -0.010474
#               runtime         0.004852
#               correct_year    0.994590
# score         name            0.016377
#               rating          0.006192
#               genre           0.027384
#               year            0.092616
#               released        0.039814
#               score           1.000000
#               votes           0.407101
#               director        0.010568
#               writer          0.022098
#               star           -0.000026
#               country        -0.133346
#               budget          0.056863
#               gross           0.186012
#               company         0.005081
#               runtime         0.394564
#               correct_year    0.038923
# votes         name            0.013038
#               rating          0.033743
#               genre          -0.145296
#               year            0.222427
#               released        0.015878
#               score           0.407101
#               votes           1.000000
#               director        0.000349
#               writer          0.001127
#               star           -0.019146
#               country         0.073525
#               budget          0.486931
#               gross           0.632870
#               company         0.133457
#               runtime         0.306984
#               correct_year    0.016978
# director      name            0.009079
#               rating          0.019483
#               genre          -0.015258
#               year           -0.020795
#               released       -0.001478
#               score           0.010568
#               votes           0.000349
#               director        1.000000
#               writer          0.299067
#               star            0.039234
#               country         0.017490
#               budget          0.004976
#               gross          -0.014916
#               company         0.004404
#               runtime         0.017062
#               correct_year   -0.000023
# writer        name            0.009081
#               rating         -0.005921
#               genre           0.006567
#               year           -0.008656
#               released       -0.002404
#               score           0.022098
#               votes           0.001127
#               director        0.299067
#               writer          1.000000
#               star            0.027245
#               country         0.015343
#               budget         -0.025911
#               gross          -0.022997
#               company         0.005646
#               runtime        -0.004036
#               correct_year   -0.002235
# star          name            0.006472
#               rating          0.013405
#               genre          -0.005477
#               year           -0.027242
#               released        0.015777
#               score          -0.000026
#               votes          -0.019146
#               director        0.039234
#               writer          0.027245
#               star            1.000000
#               country        -0.012998
#               budget         -0.019952
#               gross          -0.001129
#               company         0.012442
#               runtime         0.009418
#               correct_year    0.015330
# country       name           -0.010737
#               rating          0.081244
#               genre          -0.037615
#               year           -0.070938
#               released       -0.020427
#               score          -0.133346
#               votes           0.073525
#               director        0.017490
#               writer          0.015343
#               star           -0.012998
#               country         1.000000
#               budget          0.131720
#               gross           0.095325
#               company         0.095548
#               runtime        -0.073319
#               correct_year   -0.017117
# budget        name            0.020548
#               rating         -0.081939
#               genre          -0.334021
#               year            0.309212
#               released        0.009145
#               score           0.056863
#               votes           0.486931
#               director        0.004976
#               writer         -0.025911
#               star           -0.019952
#               country         0.131720
#               budget          1.000000
#               gross           0.750157
#               company         0.186474
#               runtime         0.268372
#               correct_year    0.011545
# gross         name            0.006989
#               rating         -0.095450
#               genre          -0.234297
#               year            0.261900
#               released        0.000519
#               score           0.186012
#               votes           0.632870
#               director       -0.014916
#               writer         -0.022997
#               star           -0.001129
#               country         0.095325
#               budget          0.750157
#               gross           1.000000
#               company         0.156745
#               runtime         0.244339
#               correct_year    0.002322
# company       name            0.009211
#               rating         -0.032943
#               genre          -0.071067
#               year           -0.010431
#               released       -0.010474
#               score           0.005081
#               votes           0.133457
#               director        0.004404
#               writer          0.005646
#               star            0.012442
#               country         0.095548
#               budget          0.186474
#               gross           0.156745
#               company         1.000000
#               runtime         0.037537
#               correct_year   -0.007622
# runtime       name            0.008483
#               rating          0.064133
#               genre          -0.052914
#               year            0.116358
#               released        0.004852
#               score           0.394564
#               votes           0.306984
#               director        0.017062
#               writer         -0.004036
#               star            0.009418
#               country        -0.073319
#               budget          0.268372
#               gross           0.244339
#               company         0.037537
#               runtime         1.000000
#               correct_year    0.007999
# correct_year  name           -0.013132
#               rating          0.012429
#               genre           0.027305
#               year           -0.002885
#               released        0.994590
#               score           0.038923
#               votes           0.016978
#               director       -0.000023
#               writer         -0.002235
#               star            0.015330
#               country        -0.017117
#               budget          0.011545
#               gross           0.002322
#               company        -0.007622
#               runtime         0.007999
#               correct_year    1.000000
# dtype: float64

# %%
sorted_pairs = corr_pairs.sort_values()

sorted_pairs
# Out:
# budget        genre          -0.334021
# genre         budget         -0.334021
# gross         genre          -0.234297
# genre         gross          -0.234297
# votes         genre          -0.145296
# genre         votes          -0.145296
# country       score          -0.133346
# score         country        -0.133346
# rating        gross          -0.095450
# gross         rating         -0.095450
# budget        rating         -0.081939
# rating        budget         -0.081939
# year          genre          -0.081261
# genre         year           -0.081261
# runtime       country        -0.073319
# country       runtime        -0.073319
# company       genre          -0.071067
# genre         company        -0.071067
# country       year           -0.070938
# year          country        -0.070938
# genre         runtime        -0.052914
# runtime       genre          -0.052914
# genre         country        -0.037615
# country       genre          -0.037615
# company       rating         -0.032943
# rating        company        -0.032943
# star          year           -0.027242
# year          star           -0.027242
# writer        budget         -0.025911
# budget        writer         -0.025911
# gross         writer         -0.022997
# writer        gross          -0.022997
# director      year           -0.020795
# year          director       -0.020795
# released      country        -0.020427
# country       released       -0.020427
# star          budget         -0.019952
# budget        star           -0.019952
# votes         star           -0.019146
# star          votes          -0.019146
# correct_year  country        -0.017117
# country       correct_year   -0.017117
# director      genre          -0.015258
# genre         director       -0.015258
# gross         director       -0.014916
# director      gross          -0.014916
# name          correct_year   -0.013132
# correct_year  name           -0.013132
# star          country        -0.012998
# country       star           -0.012998
# name          released       -0.011311
# released      name           -0.011311
# name          country        -0.010737
# country       name           -0.010737
# company       released       -0.010474
# released      company        -0.010474
# year          company        -0.010431
# company       year           -0.010431
# writer        year           -0.008656
# year          writer         -0.008656
# name          rating         -0.008069
# rating        name           -0.008069
# company       correct_year   -0.007622
# correct_year  company        -0.007622
# rating        writer         -0.005921
# writer        rating         -0.005921
# genre         star           -0.005477
# star          genre          -0.005477
# writer        runtime        -0.004036
# runtime       writer         -0.004036
# year          correct_year   -0.002885
# correct_year  year           -0.002885
# released      writer         -0.002404
# writer        released       -0.002404
# correct_year  writer         -0.002235
# writer        correct_year   -0.002235
# director      released       -0.001478
# released      director       -0.001478
# gross         star           -0.001129
# star          gross          -0.001129
# released      year           -0.000695
# year          released       -0.000695
# score         star           -0.000026
# star          score          -0.000026
# director      correct_year   -0.000023
# correct_year  director       -0.000023
# director      votes           0.000349
# votes         director        0.000349
# released      gross           0.000519
# gross         released        0.000519
# votes         writer          0.001127
# writer        votes           0.001127
# gross         correct_year    0.002322
# correct_year  gross           0.002322
# company       director        0.004404
# director      company         0.004404
# released      runtime         0.004852
# runtime       released        0.004852
# director      budget          0.004976
# budget        director        0.004976
# score         company         0.005081
# company       score           0.005081
# writer        company         0.005646
# company       writer          0.005646
# rating        score           0.006192
# score         rating          0.006192
# star          name            0.006472
# name          star            0.006472
# writer        genre           0.006567
# genre         writer          0.006567
# gross         name            0.006989
# name          gross           0.006989
# correct_year  runtime         0.007999
# runtime       correct_year    0.007999
# name          runtime         0.008483
# runtime       name            0.008483
# rating        year            0.008779
# year          rating          0.008779
# director      name            0.009079
# name          director        0.009079
# writer        name            0.009081
# name          writer          0.009081
# released      budget          0.009145
# budget        released        0.009145
# name          company         0.009211
# company       name            0.009211
# star          runtime         0.009418
# runtime       star            0.009418
# score         director        0.010568
# director      score           0.010568
# name          year            0.011453
# year          name            0.011453
# budget        correct_year    0.011545
# correct_year  budget          0.011545
#               rating          0.012429
# rating        correct_year    0.012429
# company       star            0.012442
# star          company         0.012442
# votes         name            0.013038
# name          votes           0.013038
# rating        star            0.013405
# star          rating          0.013405
#               correct_year    0.015330
# correct_year  star            0.015330
# country       writer          0.015343
# writer        country         0.015343
# star          released        0.015777
# released      star            0.015777
#               votes           0.015878
# votes         released        0.015878
# name          genre           0.016355
# genre         name            0.016355
# name          score           0.016377
# score         name            0.016377
# rating        released        0.016613
# released      rating          0.016613
# correct_year  votes           0.016978
# votes         correct_year    0.016978
# runtime       director        0.017062
# director      runtime         0.017062
# country       director        0.017490
# director      country         0.017490
# rating        director        0.019483
# director      rating          0.019483
# budget        name            0.020548
# name          budget          0.020548
# writer        score           0.022098
# score         writer          0.022098
# star          writer          0.027245
# writer        star            0.027245
# genre         correct_year    0.027305
# correct_year  genre           0.027305
# genre         score           0.027384
# score         genre           0.027384
# genre         released        0.029822
# released      genre           0.029822
# votes         rating          0.033743
# rating        votes           0.033743
# runtime       company         0.037537
# company       runtime         0.037537
# score         correct_year    0.038923
# correct_year  score           0.038923
# star          director        0.039234
# director      star            0.039234
# released      score           0.039814
# score         released        0.039814
#               budget          0.056863
# budget        score           0.056863
# runtime       rating          0.064133
# rating        runtime         0.064133
# genre         rating          0.072423
# rating        genre           0.072423
# country       votes           0.073525
# votes         country         0.073525
# rating        country         0.081244
# country       rating          0.081244
# score         year            0.092616
# year          score           0.092616
# country       gross           0.095325
# gross         country         0.095325
# country       company         0.095548
# company       country         0.095548
# year          runtime         0.116358
# runtime       year            0.116358
# country       budget          0.131720
# budget        country         0.131720
# company       votes           0.133457
# votes         company         0.133457
# gross         company         0.156745
# company       gross           0.156745
# score         gross           0.186012
# gross         score           0.186012
# budget        company         0.186474
# company       budget          0.186474
# year          votes           0.222427
# votes         year            0.222427
# runtime       gross           0.244339
# gross         runtime         0.244339
#               year            0.261900
# year          gross           0.261900
# runtime       budget          0.268372
# budget        runtime         0.268372
# director      writer          0.299067
# writer        director        0.299067
# votes         runtime         0.306984
# runtime       votes           0.306984
# year          budget          0.309212
# budget        year            0.309212
# runtime       score           0.394564
# score         runtime         0.394564
#               votes           0.407101
# votes         score           0.407101
# budget        votes           0.486931
# votes         budget          0.486931
# gross         votes           0.632870
# votes         gross           0.632870
# budget        gross           0.750157
# gross         budget          0.750157
# correct_year  released        0.994590
# released      correct_year    0.994590
# name          name            1.000000
# company       company         1.000000
# gross         gross           1.000000
# budget        budget          1.000000
# country       country         1.000000
# star          star            1.000000
# writer        writer          1.000000
# director      director        1.000000
# votes         votes           1.000000
# score         score           1.000000
# released      released        1.000000
# year          year            1.000000
# genre         genre           1.000000
# rating        rating          1.000000
# runtime       runtime         1.000000
# correct_year  correct_year    1.000000
# dtype: float64

# %%
high_corr = sorted_pairs[(sorted_pairs) > 0.5]

high_corr
# Out:
# gross         votes           0.632870
# votes         gross           0.632870
# budget        gross           0.750157
# gross         budget          0.750157
# correct_year  released        0.994590
# released      correct_year    0.994590
# name          name            1.000000
# company       company         1.000000
# gross         gross           1.000000
# budget        budget          1.000000
# country       country         1.000000
# star          star            1.000000
# writer        writer          1.000000
# director      director        1.000000
# votes         votes           1.000000
# score         score           1.000000
# released      released        1.000000
# year          year            1.000000
# genre         genre           1.000000
# rating        rating          1.000000
# runtime       runtime         1.000000
# correct_year  correct_year    1.000000
# dtype: float64

# %%
# Votes and gross have the highest correlation to gross earnings
